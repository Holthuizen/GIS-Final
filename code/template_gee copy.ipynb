# %% [markdown]
# ## Authentication
#
# After importing `ee`, the `ee.Authenticate()` line should be run once to grant the notebook access to Earth Engine using your account. This triggers the authentication flow, which is easy to complete. [Here](https://developers.google.com/earth-engine/guides/python_install#authentication), you can find a step-by-step instructions.

# %%
# %pip install earthengine-api --upgrade
# %pip install geemap
# Out:
# Requirement already satisfied: earthengine-api in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (0.1.385)
# Collecting earthengine-api
#   Downloading earthengine-api-0.1.386.tar.gz (267 kB)
#      ---------------------------------------- 0.0/267.3 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/267.3 kB 660.6 kB/s eta 0:00:01
#      ----------------------------- -------- 204.8/267.3 kB 3.1 MB/s eta 0:00:01
#      -------------------------------------- 267.3/267.3 kB 3.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: google-cloud-storage in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api) (2.14.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api) (2.113.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api) (2.26.2)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: requests in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api) (2.31.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.15.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.1.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage->earthengine-api) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage->earthengine-api) (2.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage->earthengine-api) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api) (2023.7.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (4.25.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.5.1)
# Building wheels for collected packages: earthengine-api
#   Building wheel for earthengine-api (pyproject.toml): started
#   Building wheel for earthengine-api (pyproject.toml): finished with status 'done'
#   Created wheel for earthengine-api: filename=earthengine_api-0.1.386-py3-none-any.whl size=302147 sha256=7e77546e4bde154d2572b3498f066cb9d51f651b15d0741b994baaff7f783aa6
#   Stored in directory: c:\users\cedric\appdata\local\pip\cache\wheels\c8\33\7b\7dff8790af01956b020294b27f36857ef15b9d7b3055ac2f7e
# Successfully built earthengine-api
# Installing collected packages: earthengine-api
#   Attempting uninstall: earthengine-api
#     Found existing installation: earthengine-api 0.1.385
#     Uninstalling earthengine-api-0.1.385:
#       Successfully uninstalled earthengine-api-0.1.385
# Successfully installed earthengine-api-0.1.386
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: geemap in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (0.30.4)
# Requirement already satisfied: bqplot in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (0.12.42)
# Requirement already satisfied: colour in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=0.1.347 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (0.1.386)
# Requirement already satisfied: eerepr>=0.0.4 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (0.0.4)
# Requirement already satisfied: folium>=0.13.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (0.15.1)
# Requirement already satisfied: geocoder in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.17.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (0.18.1)
# Requirement already satisfied: ipytree in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (3.8.2)
# Requirement already satisfied: numpy in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (1.24.2)
# Requirement already satisfied: pandas in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (2.1.3)
# Requirement already satisfied: plotly in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (5.18.0)
# Requirement already satisfied: pyperclip in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (1.8.2)
# Requirement already satisfied: pyshp>=2.1.3 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (7.1.1)
# Requirement already satisfied: scooby in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geemap) (0.9.2)
# Requirement already satisfied: google-cloud-storage in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.14.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.113.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.26.2)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=0.1.347->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=0.1.347->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.31.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from folium>=0.13.0->geemap) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from folium>=0.13.0->geemap) (3.1.3)
# Requirement already satisfied: xyzservices in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from folium>=0.13.0->geemap) (2023.10.1)
# Requirement already satisfied: ipywidgets in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.1)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from bqplot->geemap) (5.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from pandas->geemap) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from pandas->geemap) (2023.3)
# Requirement already satisfied: click in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geocoder->geemap) (8.1.7)
# Requirement already satisfied: future in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geocoder->geemap) (0.18.3)
# Requirement already satisfied: ratelim in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\cedric\appdata\roaming\python\python311\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from matplotlib->geemap) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from plotly->geemap) (8.2.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (2.15.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (4.9)
# Requirement already satisfied: comm>=0.1.3 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.15.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=2.9->folium>=0.13.0->geemap) (2.1.3)
# Requirement already satisfied: colorama in c:\users\cedric\appdata\roaming\python\python311\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (2023.7.22)
# Requirement already satisfied: decorator in c:\users\cedric\appdata\roaming\python\python311\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (4.25.2)
# Requirement already satisfied: backcall in c:\users\cedric\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\cedric\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\cedric\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\cedric\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\cedric\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\cedric\appdata\roaming\python\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\cedric\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\cedric\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Generated on 24/01/2024
# 4/1AfJohXnGhGa0iaZI00q6u1MVwk3UeklIp5ZYUn9hbVGCYWNz8FUqoPxWPEw

# %%
import ee
# # If you are running this notebook for the first time, you need to activate the command below for the authentication flow:
# ee.Authenticate()

# %% [markdown]
# ## Initializing
#
# Run the following scripts to initialize the API. You should see this message "Google Earth Engine has initialized successfully!"

# %%
try:
    # Initialize the library.
    ee.Initialize()
    print('Google Earth Engine has initialized successfully!')
except ee.EEException as e:
    print('Google Earth Engine has failed to initialize!')
except:
    print("Unexpected error:", sys.exc_info()[0])
    raise
# Out:
# Google Earth Engine has initialized successfully!

# %% [markdown]
# ## Getting Data and Visualizing
#
# In the GEE, datasets can be of different types:
#
# - `ee.Feature`: a geometric object with a list of properties (vector data)
# - `ee.Image`: an image that may include several bands (raster data)
# - `ee.FeatureCollection`: groups of features
# - `ee.ImageCollection`: groups of images

# %% [markdown]
# Let's use the [geemap](https://geemap.org/) Python package for defining the study area and the visualization. geemap is a Python package for interactive mapping with GEE. For video tutorials and notebook examples for the geemap Python package, please visit the [examples page](https://github.com/giswqs/geemap/tree/master/examples). For complete documentation on geemap modules and methods, please visit the [API Reference](https://geemap.org/geemap/#geemap-tutorials).

# %%
import geemap
import pickle
import os

# %% [markdown]
# Now let's call the interactive map from geemap to select a region or a point of interest. Please note that the following line opens a default basemap which is a Google Map (additional basemaps can be added using the `Map.add_basemap()` function).

# %%
Map1 = geemap.Map()
Map1
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %% [markdown]
# Now let's zoom in (using a mouse) to the region of Enschede. Using the bar at the left side of the map, select a rectangle on this map (i.e., covering Enschede  and surroundings). This region will appear as "Drawn Features" layer on this map. You can check it out using the tool icon on the top right corner of the map. Then, you can retrieve this region geometry using the following lines.

# %%
# File name where the dictionary is stored
pickle_file = 'areas_of_interest.pickle'

# Initialize the areas_of_interest dictionary
if os.path.exists(pickle_file):
    # If the pickle file exists, load the dictionary from the file
    with open(pickle_file, 'rb') as handle:
        areas_of_interest = pickle.load(handle)
    print("Loaded areas of interest from pickle file.")
else:
    # If the pickle file does not exist, initialize an empty dictionary
    areas_of_interest = {}
    print("Initialized an empty dictionary for areas of interest.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loaded areas of interest from pickle file.

# %%
if Map1.draw_last_feature is None:
    print("No new feature drawn. Nothing to retrieve.")
else:
    # Code for selecting the area
    fc = ee.FeatureCollection(Map1.draw_last_feature)
    region = fc.geometry()
    coords = region.getInfo()['coordinates']
    area_name = input("Enter a name for this area: ")

    # Check if the area name already exists in the dictionary
    if area_name in areas_of_interest:
        print(f"The area name '{area_name}' already exists. Please choose a different name.")
    else:
        # Save the coordinates with area_name as ID
        areas_of_interest[area_name] = coords
        print(f"Area '{area_name}' saved successfully.")

        # Pickling the updated dictionary
        with open('areas_of_interest.pickle', 'wb') as handle:
            pickle.dump(areas_of_interest, handle, protocol=pickle.HIGHEST_PROTOCOL)
        print("Areas of interest have been pickled and saved.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Area 'Boekelo' saved successfully.
# Areas of interest have been pickled and saved.

# %%
# Code for selecting the area
fc = ee.FeatureCollection(Map1.draw_last_feature)
region = fc.geometry()
coords = region.getInfo()['coordinates']
area_name = input("Enter a name for this area: ")

# Check if the area name already exists in the dictionary
if area_name in areas_of_interest:
    print(f"The area name '{area_name}' already exists. Please choose a different name.")
else:
    # Save the coordinates with area_name as ID
    areas_of_interest[area_name] = coords
    print(f"Area '{area_name}' saved successfully.")

    # Pickling the updated dictionary
    with open('areas_of_interest.pickle', 'wb') as handle:
        pickle.dump(areas_of_interest, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("Areas of interest have been pickled and saved.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Code for selecting the area
# ----> 2 fc = ee.FeatureCollection(Map1.draw_last_feature)
#       3 region = fc.geometry()
#       4 coords = region.getInfo()['coordinates']
#
# File c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\ee\computedobject.py:28, in ComputedObjectMetaclass.__call__(cls, *args, **kwargs)
#      26   return args[0]
#      27 else:
# ---> 28   return type.__call__(cls, *args, **kwargs)
#
# File c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\ee\_utils.py:38, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      36     if new_key not in kwargs:
#      37       kwargs[new_key] = old_key_val
# ---> 38 return func(*args, **kwargs)
#
# File c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\ee\featurecollection.py:97, in FeatureCollection.__init__(self, args, column)
#      95   super().__init__(args.func, args.args, args.varName)
#      96 else:
# ---> 97   raise ee_exception.EEException(
#      98       'Unrecognized argument type to convert to a FeatureCollection: %s' %
#      99       args)
#
# EEException: Unrecognized argument type to convert to a FeatureCollection: None

# %% [markdown]
# #### Print saved areas + coordinates

# %%
for name, coordinates in areas_of_interest.items():
    print(f"Area: {name}, Coordinates: {coordinates}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Area: Enschede, Coordinates: [[[6.795044, 52.175827], [6.795044, 52.267317], [6.985588, 52.267317], [6.985588, 52.175827], [6.795044, 52.175827]]]
# Area: Boekelo, Coordinates: [[[6.707668, 52.184142], [6.707668, 52.232951], [6.833324, 52.232951], [6.833324, 52.184142], [6.707668, 52.184142]]]

# %%
# Get user input for the area
input_area_name = input("Enter the name of the area: ")

# Check if the area name exists in the dictionary and proceed
if input_area_name in areas_of_interest:
    coordinates = areas_of_interest[input_area_name]

    # Earth Engine query using the coordinates
    myCollection = ee.ImageCollection('COPERNICUS/S2_HARMONIZED') \
        .filterBounds(ee.Geometry.Polygon(coordinates)) \
        .filterDate('2022-06-01', '2022-08-30') \
        .filterMetadata('CLOUDY_PIXEL_PERCENTAGE', 'less_than', 10)

    # Add your further processing of myCollection here
    print("Earth Engine query executed for the area:", input_area_name)
    listOfImages = myCollection.aggregate_array('system:index').getInfo()
    print('Number of images in the collection: ', len(listOfImages))

else:
    print(f"No coordinates found for the area '{input_area_name}'. Please enter a valid area name.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Earth Engine query executed for the area: Boekelo
# Number of images in the collection:  20

# %%
img1 = myCollection.first().clip(ee.Geometry.Polygon(areas_of_interest[input_area_name]))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Now it's the time to gather the Sentinel 2 images of this region. To know how to gather an specific data you can always check the [GEE data catalogue](https://developers.google.com/earth-engine/datasets). For example, according to the [Sentinel 2 satellite images catalogue ](https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR_HARMONIZED), we can access these images using the "ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")" snippet.

# %% [markdown]
# Now let's find a recent [Sentinel 2 Multispectral satellite image](https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR_HARMONIZED) that covers the selected region during the last summer. Let's consider all the images with less than 10% cloud coverage. We don't want very cloudy images!

# %% [markdown]
# The first image and clip to the region and visualize it on the map.
#
# Often, we don't need a whole image for furthur analysis. We can simply crop an image and select a smaller part of an image for the region of interest. You can use [Clip](https://developers.google.com/earth-engine/apidocs/ee-image-clip) to a Geometry or Feature for selecting part of an image. The output bands correspond exactly to the input bands, except data not covered by the geometry is masked. The output image retains the metadata of the input image.

# %%
# Some visualization parameters: 
# - Values to map to 0 and values to map to 255. 
# - Three bands to be combined as an rgb image

# You can try changing these parameters and check the result!

NIRGR = {"min": 0, 
              "max": 4000, 
              "bands": ["B8","B3","B4"]}
NIRSWIRR = {"min": 0, 
              "max": 4000, 
              "bands": ["B8","B11","B4"]}  
NIRGB = {"min": 0, 
              "max": 4000, 
              "bands": ["B8","B3","B2"]}  
SWIR2NIRR = {"min": 0, 
              "max": 4000, 
              "bands": ["B12","B8","B4"]}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map2 = geemap.Map()
vis_param = NIRGR
Map2.addLayer(img1, vis_param, "FirstImage", True) 
Map2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %% [markdown]
# Scroll and zoom to find the image!

# %% [markdown]
# We can reduce an image collection by calculating the median of all values at each pixel across the stack of all matching bands.

# %%
img2 = myCollection.median().clip(ee.Geometry.Polygon(areas_of_interest[input_area_name]))
Map2.addLayer(img2, vis_param, "MedianImage", True) 
Map2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=691039.0, center=[52.20897417980253, 6.7676639556884775], controls=(WidgetControl(options=['positio…

# %% [markdown]
# ## Exporting the Data
#
# For exporting data out of GEE we suggest to use the [geemap python package tools](https://geemap.org/notebooks/11_export_image/#download-an-eeimage).

# %%
# Let's first import some needed libraries

# %pip install rasterio
# %pip install numpy
# %pip install matplotlib

import os
import rasterio
import numpy as np
import matplotlib.pyplot as plt
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# let's create a Downloads folder and define a name for the data.

out_dir = os.path.join(os.path.expanduser('~'), 'Downloads')
vis_param_str = f"{vis_param['min']}_{vis_param['max']}_" + "_".join(vis_param['bands'])
filename = os.path.join(out_dir, f'{input_area_name}_{vis_param_str}.tif')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Exporting all bands as one single image
# By "file_per_band=True" you can export each band as one image
# With the "scale" parameter you can change the spatial resolution of the exported image. 
# Higher spatial resolution (lower scale) leads to longer downloading time.

# geemap.ee_export_image(
#     img2, filename=filename, scale=25, region=areas_of_interest[input_area_name], file_per_band=True
# )
scale = 10
geemap.ee_export_image_to_drive(
    img2, 
    description=f'{input_area_name}_{scale}', 
    folder='export', 
    scale=scale, 
    region=areas_of_interest[input_area_name]
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Now let's check if the data has been downloaded. Remember that we can open the image (raster data) using rasterio and visualize it.

# %% [markdown]
# # 'export'? using teacher method

# %%
with rasterio.open(filename, 'r') as ds:
    img = ds.read()  # read all raster values

img = img[0:12,:,:] # 12 spectral bands
img = np.transpose(img, [1, 2, 0]) # numpy array [row, col, bands]
print(img.shape)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# (378, 787, 12)

# %%
# B8-->NIR
# B4-->Red
# B3-->Green

# remember the indexes in NumPy arrays start with 0 --> bands begin from 0!

img_rgb = img[:,:,[7,3,2]]
print(img_rgb.shape)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# (378, 787, 3)

# %%
# This function normalizes each rgb band and helps you to have a better visualization.

def MyNormalize(img_i,sigma):
    nr,nc,nb = img_i.shape
    img_n = np.zeros(shape=(nr,nc,nb))
    for i in range(0,nb):
        one_band = img_i[:,:,i]
        mi = np.min(one_band)
        ma = np.max(one_band)
        one_band = (one_band-mi)/(ma-mi+np.finfo(float).eps)
        img_n[:,:,i] = sigma*one_band
    return img_n

plt.imshow(MyNormalize(img_rgb,2))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # histogram

# %%
import rasterio
import matplotlib.pyplot as plt

# Define the path to your TIFF file
tif_path = 'C:/Users/cedric/Downloads/Enschede_0_4000_B8_B3_B4.tif'

# Band indices for NIR, Green, and Red (zero-based)
bands = {"NIR": 7, "Green": 2, "Red": 3}

# Open the TIFF file
with rasterio.open(tif_path) as src:
    # Read each band and create histograms
    for band_name, band_idx in bands.items():
        band_data = src.read(band_idx + 1)  # Adding 1 because rasterio uses 1-based indexing

        # Plotting the histogram
        plt.figure()
        plt.hist(band_data.flatten(), bins=100, color='gray')
        plt.title(f'Histogram for {band_name} Band')
        plt.xlabel('Pixel values')
        plt.ylabel('Frequency')
        plt.grid(True)

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
file_path = 'C:/Users/cedric/Downloads/Enschede_0_4000_B8_B3_B4.tif'
ee_image = geemap.ee.Image(file_path)
displayMap = geemap.Map()
# Add the image to the Map using the visualization parameters
displayMap.addLayer(ee_image, NIRGR, 'NIRGR Visualization')

# Set the map center and zoom level
displayMap.setCenter(6.895, 52.2215, 10) # Coordinates for Enschede, adjust as needed

# Display the Map
displayMap
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\ee\data.py", line 395, in _execute_cloud_call
#     except googleapiclient.errors.HttpError as e:
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\_helpers.py", line 130, in positional_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\http.py", line 938, in execute
#     raise HttpError(resp, content, uri=self.uri)
# googleapiclient.errors.HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps?fields=name&alt=json returned "Image.load: Image asset 'C:/Users/cedric/Downloads/Enschede_0_4000_B8_B3_B4.tif' not found (does not exist or caller does not have access).". Details: "Image.load: Image asset 'C:/Users/cedric/Downloads/Enschede_0_4000_B8_B3_B4.tif' not found (does not exist or caller does not have access).">
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\cedric\AppData\Local\Temp\ipykernel_19224\2962220799.py", line 5, in <module>
#     displayMap.addLayer(ee_image, NIRGR, 'NIRGR Visualization')
#   File "c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\geemap\geemap.py", line 342, in add_ee_layer
#     super().add_layer(ee_object, vis_params, name, shown, opacity)
#   File "c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\geemap\core.py", line 754, in add_layer
#     tile_layer = ee_tile_layers.EELeafletTileLayer(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\geemap\ee_tile_layers.py", line 144, in __init__
#     self.url_format = _get_tile_url_format(
#                       ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\geemap\ee_tile_layers.py", line 19, in _get_tile_url_format
#     map_id_dict = ee.Image(image).getMapId(vis_params)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\ee\image.py", line 130, in getMapId
#     response['image'] = self
#                ^^^^^^^^^^^^^^
#   File "c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\ee\data.py", line 717, in getMapId
#     _get_cloud_projects()
#          ^^^^^^^^^^^^^^^^
#   File "c:\Users\cedric\AppData\Local\Programs\Python\Python311\Lib\site-packages\ee\data.py", line 397, in _execute_cloud_call
# ee.ee_exception.EEException: Image.load: Image asset 'C:/Users/cedric/Downloads/Enschede_0_4000_B8_B3_B4.tif' not found (does not exist or caller does not have access).
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "C:\Users\cedric\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %% [markdown]
# You can also export an image to Google Drive using the following line of code. This could be useful for example for big images. Moreover, you can download an image collection using geemap tools. See [this tutorial](https://geemap.org/notebooks/11_export_image/#exporting-all-bands-as-one-single-image) for more details.

# %%
def read_tif_as_rgb(tif_path):
    """
    Read a tif file as a numpy array
    """
    with rasterio.open(tif_path) as src:
        raw_img =  src.read()
        img_t = np.transpose(raw_img[0:12,:,:], [1,2,0])
    return img_t[:,:,[3,2,1]] #select r,b,g chanels



def rgb_color_normalization(three_band_img,sigma):
    rows,columns,bands = three_band_img.shape
    #place holder np array
    img_normalized = np.ones(shape=(rows,columns,bands))
    #normalization of each band
    for i in range(0,bands):
        band = three_band_img[:,:,i]
        band = (band - np.min(band)) / (np.max(band) - np.min(band))
        img_normalized[:,:,i] *= band
    return img_normalized * sigma


def save_normalized_image(img_rgb, filename):

  fig, ax = plt.subplots()
  ax.imshow(img_rgb)
  
  dpi = 300
  plt.savefig(filename, dpi=dpi)

  # Close the figure 
  plt.close(fig)

  print(f"Saved normalized image to {filename} at {dpi} DPI")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#example workflow
#load a GEE satellite img as a tif with all of its bands
img = read_tif_as_rgb("C:/Users/cedric/Downloads/Enschede_0_4000_B8_B4_B3.tif")
#get a normalized rgb img by selecting 3 bands
img_normalized = rgb_color_normalization(img,4) 
#show the img
plt.imshow(img_normalized)
#save the rgb img if needed
if True:
    save_normalized_image(img_rgb = img_normalized, filename='normalized.png')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saved normalized image to normalized.png at 300 DPI
